# %%
#import the necessary tools.
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('titanic2.csv')
desc = data.describe()
#data.info()
desc
# Out:
#          Survived      Pclass            ID         Age  \
# count  887.000000  887.000000    887.000000  887.000000
# mean     0.385569    2.305524  60239.794814   29.471443
# std      0.487004    0.836662  11435.837096   14.121908
# min      0.000000    1.000000  40074.000000    0.420000
# 25%      0.000000    2.000000  50063.000000   20.250000
# 50%      0.000000    3.000000  60448.000000   28.000000
# 75%      1.000000    3.000000  70344.000000   38.000000
# max      1.000000    3.000000  79907.000000   80.000000
#
#        Siblings/Spouses Aboard  Parents/Children Aboard       Fare
# count               887.000000               887.000000  887.00000
# mean                  0.525366                 0.383315   32.30542
# std                   1.104669                 0.807466   49.78204
# min                   0.000000                 0.000000    0.00000
# 25%                   0.000000                 0.000000    7.92500
# ...

# %%
#determine columns with missing values.
data['missingVal'] = data.isnull().sum()
#rename sex to gender.
data = data.rename(columns = {"Sex":"Gender", "ID": "Id"})
data
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                             Mr. Owen Harris Braund
# 1           1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2           1       3                              Miss. Laina Heikkinen
# 3           1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4           0       3                            Mr. William Henry Allen
# ..        ...     ...                                                ...
# 882         0       2                               Rev. Juozas Montvila
# 883         1       1                        Miss. Margaret Edith Graham
# 884         0       3                     Miss. Catherine Helen Johnston
# 885         1       1                               Mr. Karl Howell Behr
# 886         0       3                                 Mr. Patrick Dooley
#
#      Gender     Id   Age  Siblings/Spouses Aboard  Parents/Children Aboard  \
# ...

# %%
#shape of the data.
data.shape
# Out:
# (887, 10)

# %%
# detemine the number of people that survived
survived = data['Survived'].count()
survived
# Out:
# 887

# %%
#univariate analysis.

# %%
sns.set(style ="darkgrid")
sns.countplot(x="Survived" ,data=data, hue="Survived")
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x="Pclass" ,data=data, hue="Survived")
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='count'>

# %%
sns.scatterplot(y="Age",x="Survived" ,data=data, hue="Pclass" ).set_title("scatter plot")
# Out:
# Text(0.5, 1.0, 'scatter plot')

# %%
#increase fere by 2% as fare inc
data["fareinc"] = data['Fare'] * 102
data
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                             Mr. Owen Harris Braund
# 1           1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2           1       3                              Miss. Laina Heikkinen
# 3           1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4           0       3                            Mr. William Henry Allen
# ..        ...     ...                                                ...
# 882         0       2                               Rev. Juozas Montvila
# 883         1       1                        Miss. Margaret Edith Graham
# 884         0       3                     Miss. Catherine Helen Johnston
# 885         1       1                               Mr. Karl Howell Behr
# 886         0       3                                 Mr. Patrick Dooley
#
#      Gender     Id   Age  Siblings/Spouses Aboard  Parents/Children Aboard  \
# ...

# %%
#drop column "funny"
data.drop('funny', axis=1, inplace=True)
data
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                             Mr. Owen Harris Braund
# 1           1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2           1       3                              Miss. Laina Heikkinen
# 3           1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4           0       3                            Mr. William Henry Allen
# ..        ...     ...                                                ...
# 882         0       2                               Rev. Juozas Montvila
# 883         1       1                        Miss. Margaret Edith Graham
# 884         0       3                     Miss. Catherine Helen Johnston
# 885         1       1                               Mr. Karl Howell Behr
# 886         0       3                                 Mr. Patrick Dooley
#
#      Gender     Id   Age  Siblings/Spouses Aboard  Parents/Children Aboard  \
# ...

# %% [markdown]
# #remove column missingval

# %%
data.drop('missingVal', axis=1, inplace= True)
data
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                             Mr. Owen Harris Braund
# 1           1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2           1       3                              Miss. Laina Heikkinen
# 3           1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4           0       3                            Mr. William Henry Allen
# ..        ...     ...                                                ...
# 882         0       2                               Rev. Juozas Montvila
# 883         1       1                        Miss. Margaret Edith Graham
# 884         0       3                     Miss. Catherine Helen Johnston
# 885         1       1                               Mr. Karl Howell Behr
# 886         0       3                                 Mr. Patrick Dooley
#
#      Gender     Id   Age  Siblings/Spouses Aboard  Parents/Children Aboard  \
# ...
